# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholas-dinicola/Forecasting-stock-prices-based-on-semantic-analysis-of-business-news-and-social-media-posts-/blob/main/Stock_%2B_USE_%2B_Polarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas_datareader as pdr
from datetime import datetime
import os
from joblib import dump, load
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss, acf, pacf
import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.metrics import mean_squared_error
import time
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
import tensorflow as tf
import tensorflow_hub as hub
tf.get_logger().setLevel('ERROR')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Mean Directional Accuracy
def get_mda(y, yhat):
    """Mean Directional Accuracy, as per:
    https://www.wikiwand.com/en/Mean_Directional_Accuracy
    """
    a = np.sign(np.diff(y))
    b = np.sign(np.diff(yhat))
    return np.sum(a == b)/a.shape[0]

# %% [markdown]
# # Load the TSLA Historical Price Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''# Tesla
start_date = "2016/01/01"
end_date = "2021/05/01"

tlsa_stock = pdr.data.get_data_yahoo("TSLA", start=start_date, end = end_date)
tlsa_stock.head(), tlsa_stock.shape'''
# Out:
# '# Tesla\nstart_date = "2016/01/01"\nend_date = "2021/05/01"\n\ntlsa_stock = pdr.data.get_data_yahoo("TSLA", start=start_date, end = end_date)\ntlsa_stock.head(), tlsa_stock.shape'

# %%
tlsa_stock = pd.read_csv("/content/drive/MyDrive/TLSA_stock.csv")
tlsa_stock.head()
# Out:
#          Date       High        Low  ...      Close      Volume  Adj Close
# 0  2016-01-04  46.276001  43.799999  ...  44.681999  34135500.0  44.681999
# 1  2016-01-05  45.377998  44.000000  ...  44.686001  15934000.0  44.686001
# 2  2016-01-06  44.009998  43.195999  ...  43.807999  18895500.0  43.807999
# 3  2016-01-07  43.688000  42.734001  ...  43.130001  17771500.0  43.130001
# 4  2016-01-08  44.088001  42.153999  ...  42.200001  18140500.0  42.200001
#
# [5 rows x 7 columns]

# %%
tlsa_stock["Date"] = pd.to_datetime(tlsa_stock["Date"], format="%Y-%m-%d")
tlsa_stock.set_index("Date", inplace=True)
tlsa_stock.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2016-01-04  46.276001  43.799999  46.144001  44.681999  34135500.0  44.681999
# 2016-01-05  45.377998  44.000000  45.271999  44.686001  15934000.0  44.686001
# 2016-01-06  44.009998  43.195999  44.000000  43.807999  18895500.0  43.807999
# 2016-01-07  43.688000  42.734001  42.838001  43.130001  17771500.0  43.130001
# 2016-01-08  44.088001  42.153999  43.571999  42.200001  18140500.0  42.200001

# %%
tlsa_stock.index.min(), tlsa_stock.index.max()
# Out:
# (Timestamp('2016-01-04 00:00:00'), Timestamp('2021-04-30 00:00:00'))

# %%
tlsa_stock.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %% [markdown]
# # Reddit Submissions

# %%
tesla = pd.read_csv("/content/drive/MyDrive/reddit_queries-TSLA stock-2016-01-01-2021-05-01-submission.csv", usecols=["created", "text", "polarity"])

tesla.head()
# Out:
#                created  ...  polarity
# 0  2016-01-04 18:56:15  ...  0.000000
# 1  2016-01-07 17:03:55  ...  0.000000
# 2  2016-01-09 01:22:58  ...  0.437500
# 3  2016-01-10 09:00:21  ...  0.000000
# 4  2016-01-14 01:39:10  ...  0.136364
#
# [5 rows x 3 columns]

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11175 entries, 0 to 11174
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   created   11175 non-null  object
#  1   text      11175 non-null  object
#  2   polarity  11175 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 262.0+ KB

# %%
# Convert the Created column to the correct datatype
tesla["created"] = pd.to_datetime(tesla["created"], format="%Y-%m-%d %X")

# Rename the column to Date eeee
tesla.rename(columns={
                      "created": "Date", 
                      "text": "Text", 
                      "polarity": "Polarity"
                      }, 
                      inplace=True
                      )

# Delite the time from the date 
tesla["Date"] = tesla["Date"].dt.date

# Set date as the index 
#tesla.set_index("date", inplace=True)

tesla.head()
# Out:
#          Date                                               Text  Polarity
# 0  2016-01-04          Why the TSLA Stock Price Dropped 7% Today  0.000000
# 1  2016-01-07     How will the Chinese market effect TSLA stock?  0.000000
# 2  2016-01-09  If you feel a stock will rise significantly wh...  0.437500
# 3  2016-01-10                   Some help with respective growth  0.000000
# 4  2016-01-14  New to investing - how does a stock being "ove...  0.136364

# %%
tesla.isnull().sum()
# Out:
# Date        0
# Text        0
# Polarity    0
# dtype: int64

# %% [markdown]
# ## *Text Processing*

# %%
print(f"Original dataset: {tesla.shape}")
# Drop duplicate submissions 
tesla.drop_duplicates(subset=["Text"], inplace=True)

print(f"Dropped Duplicates: {tesla.shape}")
# Out:
# Original dataset: (11175, 3)
# Dropped Duplicates: (9422, 3)

# %%
# Drop submission containing words: I, me, my 
tesla_cleaned = tesla[~tesla["Text"].str.contains("|".join(["I", "me", "my", "Me", "My"]))]
tesla_cleaned.shape
# Out:
# (5564, 3)

# %% [markdown]
# ## *Universal Sentence Encoder - Transformer Neural Network*

# %%
# load the model
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder-large/5")

# %%
# Embed the text 
embeddings = embed(tesla_cleaned["Text"])
embeddings
# Out:
# <tf.Tensor: shape=(5564, 512), dtype=float32, numpy=
# array([[ 0.0434556 , -0.11120631,  0.03928241, ..., -0.05267136,
#         -0.02853705,  0.03992588],
#        [ 0.05424884, -0.10001908,  0.00567574, ..., -0.06127234,
#         -0.0198233 ,  0.0527487 ],
#        [ 0.03904071, -0.06860577,  0.01309198, ..., -0.09000869,
#         -0.01731982,  0.01975582],
#        ...,
#        [ 0.04847564, -0.06918482,  0.01885642, ..., -0.11346153,
#          0.00420032,  0.06121937],
#        [ 0.02811337, -0.09642214, -0.03425786, ...,  0.02870709,
#          0.00932993,  0.04918297],
#        [ 0.05211927, -0.01738227, -0.03032009, ..., -0.03761018,
#          0.05486577,  0.06084002]], dtype=float32)>

# %%
# Similarity
sim_matrix = np.inner(embeddings, embeddings)
sim_matrix
# Out:
# array([[0.9999998 , 0.6547644 , 0.46472248, ..., 0.19412833, 0.24112663,
#         0.27285296],
#        [0.6547644 , 0.99999976, 0.5148665 , ..., 0.21957847, 0.25637963,
#         0.24683434],
#        [0.46472248, 0.5148665 , 0.99999976, ..., 0.20974058, 0.18578179,
#         0.16128165],
#        ...,
#        [0.19412833, 0.21957847, 0.20974058, ..., 0.9999999 , 0.17004207,
#         0.35178077],
#        [0.24112663, 0.25637963, 0.18578179, ..., 0.17004207, 0.9999999 ,
#         0.35338065],
#        [0.27285296, 0.24683434, 0.16128165, ..., 0.35178077, 0.35338065,
#         0.99999994]], dtype=float32)

# %%
# Tensorflow embeddings to numpy array  
embeddings_array = embeddings.numpy()

# Add the arrays in a Dataframe with shape 5564, 512
df_embed = pd.DataFrame(embeddings_array)
df_embed
# Out:
#            0         1         2    ...       509       510       511
# 0     0.043456 -0.111206  0.039282  ... -0.052671 -0.028537  0.039926
# 1     0.054249 -0.100019  0.005676  ... -0.061272 -0.019823  0.052749
# 2     0.039041 -0.068606  0.013092  ... -0.090009 -0.017320  0.019756
# 3    -0.009967 -0.035609 -0.008195  ... -0.050620  0.033360  0.070762
# 4     0.041209 -0.126977  0.017845  ... -0.085929 -0.000526  0.058836
# ...        ...       ...       ...  ...       ...       ...       ...
# 5559  0.096124 -0.113736  0.031400  ... -0.054470 -0.024180 -0.003716
# 5560  0.005917 -0.095915  0.036277  ... -0.083284 -0.004281  0.019781
# 5561  0.048476 -0.069185  0.018856  ... -0.113462  0.004200  0.061219
# 5562  0.028113 -0.096422 -0.034258  ...  0.028707  0.009330  0.049183
# 5563  0.052119 -0.017382 -0.030320  ... -0.037610  0.054866  0.060840
#
# [5564 rows x 512 columns]

# %% [markdown]
# ## *Join the Embedded Dataframe with the Reddit one*

# %%
tesla_cleaned.shape, df_embed.shape
# Out:
# ((5564, 3), (5564, 512))

# %%
# Drop the original text column from the Tesla dataset 
tesla_NoText = tesla_cleaned.drop(["Text"], axis=1)

# Combine the embedded text dataset with the Tesla dataset
tesla_embed = pd.concat([tesla_NoText.reset_index(), df_embed], axis=1)

# Drop the index 
tesla_embed.drop(["index"], axis=1, inplace=True)

# Expecting a shape of 5564, 514
tesla_embed.shape == (5564, 514)
# Out:
# True

# %%
# See the head of the embedded tesla dataset
tesla_embed
# Out:
#             Date  Polarity         0  ...       509       510       511
# 0     2016-01-04  0.000000  0.043456  ... -0.052671 -0.028537  0.039926
# 1     2016-01-07  0.000000  0.054249  ... -0.061272 -0.019823  0.052749
# 2     2016-01-14  0.136364  0.039041  ... -0.090009 -0.017320  0.019756
# 3     2016-01-17  0.500000 -0.009967  ... -0.050620  0.033360  0.070762
# 4     2016-01-20 -0.077778  0.041209  ... -0.085929 -0.000526  0.058836
# ...          ...       ...       ...  ...       ...       ...       ...
# 5559  2021-04-30  0.125000  0.096124  ... -0.054470 -0.024180 -0.003716
# 5560  2021-04-30  0.200000  0.005917  ... -0.083284 -0.004281  0.019781
# 5561  2021-04-30  0.000000  0.048476  ... -0.113462  0.004200  0.061219
# 5562  2021-05-01  0.000000  0.028113  ...  0.028707  0.009330  0.049183
# 5563  2021-05-01  0.000000  0.052119  ... -0.037610  0.054866  0.060840
#
# [5564 rows x 514 columns]

# %%
# Convert the Date column to a datetime object 
tesla_embed["Date"] = pd.to_datetime(tesla_embed["Date"], format="%Y-%m-%d")
tesla_embed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5564 entries, 0 to 5563
# Columns: 514 entries, Date to 511
# dtypes: datetime64[ns](1), float32(512), float64(1)
# memory usage: 11.0 MB

# %% [markdown]
# ## *Join the Tesla embedded dataset with the TLSA Historical price dataset*

# %%
# Create a list of all possible dates 
start_date = "2016-01-04"
end_date = "2021/05/01"
my_dates = pd.date_range(start=start_date, end=end_date)

# Store the list of dates in a dateframe 
df_date = pd.DataFrame(my_dates).rename(columns={0: "Date"})
df_date
# Out:
#            Date
# 0    2016-01-04
# 1    2016-01-05
# 2    2016-01-06
# 3    2016-01-07
# 4    2016-01-08
# ...         ...
# 1940 2021-04-27
# 1941 2021-04-28
# 1942 2021-04-29
# 1943 2021-04-30
# 1944 2021-05-01
#
# [1945 rows x 1 columns]

# %%
# Merge the Date Df with the tesla Embed to obtain a dataset with all possible dates 
tesla_date_embed = df_date.merge(tesla_embed, on="Date", how="outer")
tesla_date_embed
# Out:
#            Date  Polarity         0  ...       509       510       511
# 0    2016-01-04     0.000  0.043456  ... -0.052671 -0.028537  0.039926
# 1    2016-01-05       NaN       NaN  ...       NaN       NaN       NaN
# 2    2016-01-06       NaN       NaN  ...       NaN       NaN       NaN
# 3    2016-01-07     0.000  0.054249  ... -0.061272 -0.019823  0.052749
# 4    2016-01-08       NaN       NaN  ...       NaN       NaN       NaN
# ...         ...       ...       ...  ...       ...       ...       ...
# 6283 2021-04-30     0.125  0.096124  ... -0.054470 -0.024180 -0.003716
# 6284 2021-04-30     0.200  0.005917  ... -0.083284 -0.004281  0.019781
# 6285 2021-04-30     0.000  0.048476  ... -0.113462  0.004200  0.061219
# 6286 2021-05-01     0.000  0.028113  ...  0.028707  0.009330  0.049183
# 6287 2021-05-01     0.000  0.052119  ... -0.037610  0.054866  0.060840
#
# [6288 rows x 514 columns]

# %%
# The tlsa_stoco df is indexed by the Date and we need it for the join, 
# thereby we need to reset the index and filter the dataset only by the  variable we are interested 

tlsa_stock = tlsa_stock["Close"].reset_index()

# Left join tlsa_stock with tesla_date_embed 
tesla_merged = tesla_date_embed.merge(tlsa_stock, on="Date", how="left")
tesla_merged
# Out:
#            Date  Polarity         0  ...       510       511       Close
# 0    2016-01-04     0.000  0.043456  ... -0.028537  0.039926   44.681999
# 1    2016-01-05       NaN       NaN  ...       NaN       NaN   44.686001
# 2    2016-01-06       NaN       NaN  ...       NaN       NaN   43.807999
# 3    2016-01-07     0.000  0.054249  ... -0.019823  0.052749   43.130001
# 4    2016-01-08       NaN       NaN  ...       NaN       NaN   42.200001
# ...         ...       ...       ...  ...       ...       ...         ...
# 6283 2021-04-30     0.125  0.096124  ... -0.024180 -0.003716  709.440002
# 6284 2021-04-30     0.200  0.005917  ... -0.004281  0.019781  709.440002
# 6285 2021-04-30     0.000  0.048476  ...  0.004200  0.061219  709.440002
# 6286 2021-05-01     0.000  0.028113  ...  0.009330  0.049183         NaN
# 6287 2021-05-01     0.000  0.052119  ...  0.054866  0.060840         NaN
#
# [6288 rows x 515 columns]

# %% [markdown]
# ## *Clean up the Final Dataset*
#
# We need to obtain a dataset with only a representation of a single day for each day. Hence, we can group by date taking the mean of all the other numerical columns.

# %%
# Group by date taking the mean for the other columns 
tesla_grouped = tesla_merged.groupby("Date").mean()
tesla_grouped
# Out:
#             Polarity         0         1  ...       510       511       Close
# Date                                      ...
# 2016-01-04  0.000000  0.043456 -0.111206  ... -0.028537  0.039926   44.681999
# 2016-01-05       NaN       NaN       NaN  ...       NaN       NaN   44.686001
# 2016-01-06       NaN       NaN       NaN  ...       NaN       NaN   43.807999
# 2016-01-07  0.000000  0.054249 -0.100019  ... -0.019823  0.052749   43.130001
# 2016-01-08       NaN       NaN       NaN  ...       NaN       NaN   42.200001
# ...              ...       ...       ...  ...       ...       ...         ...
# 2021-04-27  0.123897  0.036748 -0.064050  ...  0.011213  0.049618  704.739990
# 2021-04-28  0.228571  0.033096 -0.061462  ...  0.015648  0.042540  694.400024
# 2021-04-29  0.020370  0.049232 -0.076788  ...  0.007516  0.044927  677.000000
# 2021-04-30  0.151389  0.036359 -0.042825  ...  0.035637  0.039783  709.440002
# 2021-05-01  0.000000  0.040116 -0.056902  ...  0.032098  0.055011         NaN
#
# [1945 rows x 514 columns]

# %% [markdown]
# ### *Missing Values*

# %%
# Foward fill missing values 
final_tesla = tesla_grouped.fillna(method="ffill", axis=0)
final_tesla
# Out:
#             Polarity         0         1  ...       510       511       Close
# Date                                      ...
# 2016-01-04  0.000000  0.043456 -0.111206  ... -0.028537  0.039926   44.681999
# 2016-01-05  0.000000  0.043456 -0.111206  ... -0.028537  0.039926   44.686001
# 2016-01-06  0.000000  0.043456 -0.111206  ... -0.028537  0.039926   43.807999
# 2016-01-07  0.000000  0.054249 -0.100019  ... -0.019823  0.052749   43.130001
# 2016-01-08  0.000000  0.054249 -0.100019  ... -0.019823  0.052749   42.200001
# ...              ...       ...       ...  ...       ...       ...         ...
# 2021-04-27  0.123897  0.036748 -0.064050  ...  0.011213  0.049618  704.739990
# 2021-04-28  0.228571  0.033096 -0.061462  ...  0.015648  0.042540  694.400024
# 2021-04-29  0.020370  0.049232 -0.076788  ...  0.007516  0.044927  677.000000
# 2021-04-30  0.151389  0.036359 -0.042825  ...  0.035637  0.039783  709.440002
# 2021-05-01  0.000000  0.040116 -0.056902  ...  0.032098  0.055011  709.440002
#
# [1945 rows x 514 columns]

# %%
final_tesla.isnull().any().sum()
# Out:
# 0

# %%
final_tesla["Close"].plot(figsize=(16, 8))
plt.grid(True)
plt.title("TSLA Close Stock Price", fontsize=16)
# Out:
# Text(0.5, 1.0, 'TSLA Close Stock Price')

# %% [markdown]
# Data after 2019/09/01 became too volatile, thereby i will not include those data in the model.

# %%
final_tesla = final_tesla[final_tesla.index < "2019/09/01"]
final_tesla.index.min(), final_tesla.index.max()
# Out:
# (Timestamp('2016-01-04 00:00:00'), Timestamp('2019-08-31 00:00:00'))

# %%
final_tesla["Close"].plot(figsize=(16, 8))
plt.grid(True)
plt.title("TSLA Close Stock Price", fontsize=16)
# Out:
# Text(0.5, 1.0, 'TSLA Close Stock Price')

# %%
final_tesla.shape
# Out:
# (1336, 514)

# %% [markdown]
# # Stock Price + Text Embeddings + Polarity Score

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
train_set, test_set = train_test_split(final_tesla, test_size=0.1, random_state=42, shuffle=False)
print(f"{train_set.shape[0]} train and {test_set.shape[0]} test instances")
# Out:
# 1202 train and 134 test instances

# %%
pd.DataFrame({"train":train_set["Close"], "test":test_set["Close"]}).plot(figsize=(16, 8))
plt.title("TSLA Close Stock Price", fontsize=16)
plt.grid(True)

# %% [markdown]
# # Data Tranformation

# %%
train_log = np.log(train_set["Close"])
test_log = np.log(test_set["Close"])

# %%
pd.DataFrame({"train":train_log, "test":test_log}).plot(figsize=(16, 8))
plt.title("TSLA Close Stock Price", fontsize=16)
plt.grid(True)

# %%
# Differencing 
train_diff = train_log.diff().dropna()
adf_pval = adfuller(train_diff)[1]
print(f"ADF, p-value: {adf_pval}")
kpss_stat, kpss_pval, lags, crit_vals = kpss(train_diff)
print(f"KPSS, p-value: {kpss_pval}")

# Apply differencing to the test set as well 
test_diff = test_log.diff().dropna()

# chech the shape of them 
train_diff.shape, test_diff.shape
# Out:
# ADF, p-value: 0.0
# KPSS, p-value: 0.1
# ((1201,), (133,))

# %%
pd.DataFrame({"train":train_diff, "test":test_diff}).plot(figsize=(16, 8))
plt.title("TSLA Close Stock Price - Stationary", fontsize=16)
plt.grid(True)

# %% [markdown]
# There still are some spikes in the data, what would happen if we did the log of them?

# %%
# 5 days - from monday to friday (stock market is closedsat and sun)
lags = 5
X_train, y_train, X_test, y_test= [], [], [], []

for x in range(lags, len(train_diff.values.reshape(-1, 1))):
    X_train.append(train_diff.values.reshape(-1, 1)[x-lags:x, 0])
    y_train.append(train_diff.values.reshape(-1, 1)[x, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

for x in range(lags, len(test_diff.values.reshape(-1, 1))):
    X_test.append(test_diff.values.reshape(-1, 1)[x-lags:x, 0])
    y_test.append(test_diff.values.reshape(-1, 1)[x, 0])
X_test, y_test = np.array(X_test), np.array(y_test)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1196, 5), (1196,), (128, 5), (128,))

# %%
exog_train = train_set.drop("Close", axis=1)
exog_test = test_set.drop("Close", axis=1)

# %%
X_train = pd.concat([pd.DataFrame(X_train), exog_train.reset_index()], axis=1).drop("Date", axis=1).dropna()
X_test = pd.concat([pd.DataFrame(X_test), exog_test.reset_index()], axis=1).drop("Date", axis=1).dropna()

# %%
X_train.head()
# Out:
#         0         1         2    ...       509       510       511
# 0  0.000090 -0.019844 -0.015598  ... -0.052671 -0.028537  0.039926
# 1 -0.019844 -0.015598 -0.021799  ... -0.052671 -0.028537  0.039926
# 2 -0.015598 -0.021799  0.000000  ... -0.052671 -0.028537  0.039926
# 3 -0.021799  0.000000  0.000000  ... -0.061272 -0.019823  0.052749
# 4  0.000000  0.000000 -0.015041  ... -0.061272 -0.019823  0.052749
#
# [5 rows x 518 columns]

# %%
X_test.head()
# Out:
#         0         1         2    ...       509       510       511
# 0  0.000000 -0.039221  0.004367  ... -0.017984  0.040852  0.055679
# 1 -0.039221  0.004367 -0.020056  ... -0.017984  0.040852  0.055679
# 2  0.004367 -0.020056 -0.043579  ... -0.053520  0.004821  0.068851
# 3 -0.020056 -0.043579 -0.051755  ... -0.040849 -0.007758  0.059862
# 4 -0.043579 -0.051755  0.000000  ... -0.046375  0.027493  0.054437
#
# [5 rows x 518 columns]

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Modelling
#
# Create a folder in which store all the trained models.

# %% [markdown]
# ## SVR 1

# %%
svr = SVR(kernel="rbf")

params = [
        {
            "C": [0.001, 0.005, 0.01, 0.05, 0.1, 1.0],
            "epsilon": [0.001, 0.01],
            "gamma": [0.01, 0.1, "scale", "auto"], 
            "degree": [3, 6, 9]
        }
        ]


tscv = TimeSeriesSplit(n_splits=5)
svr_cv = GridSearchCV(estimator=svr, cv=tscv,
                        param_grid=params,
                        scoring='neg_mean_squared_error', 
                        return_train_score=True)

start = time.time()
svr_cv.fit(X_train, y_train)
duration = time.time() - start
print(f'Took {duration:.3f} seconds')
# Out:
# Took 135.071 seconds

# %%
svr_cv.best_params_
# Out:
# {'C': 0.001, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}

# %%
print(f"RMSE CV: {np.sqrt(-svr_cv.best_score_)}")
print(f"MDA TRAINING SET: {get_mda(y_train, svr_cv.predict(X_train))}")
# Out:
# RMSE CV: 0.023900020869824855
# MDA TRAINING SET: 0.6217573221757322

# %%
plt.figure(figsize=(14,6))
 
y_hat_train = svr_cv.predict(X_train)
plt.plot(y_train, label="Actual")
plt.plot((y_hat_train), label="Predicted")
plt.legend()
plt.title("Train Dataset")
# Out:
# Text(0.5, 1.0, 'Train Dataset')

# %%
val_scores = svr_cv.cv_results_["mean_test_score"]
train_scores = svr_cv.cv_results_["mean_train_score"]
params = [str(x) for x in svr_cv.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 0.023900020869824855 0.020778577586618576 {'C': 0.001, 'degree': 9, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023900020869824855 0.020778577586618576 {'C': 0.001, 'degree': 6, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023900020869824855 0.020778577586618576 {'C': 0.001, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.02390039633561047 0.020775914363325192 {'C': 0.001, 'degree': 9, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02390039633561047 0.020775914363325192 {'C': 0.001, 'degree': 6, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02390039633561047 0.020775914363325192 {'C': 0.001, 'degree': 3, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.023902757116090623 0.020628396691613454 {'C': 0.001, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.01}
# 0.023902757116090623 0.020628396691613454 {'C': 0.001, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.01}
# 0.023902757116090623 0.020628396691613454 {'C': 0.001, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.01}
# 0.02390546398814444 0.020527903107714917 {'C': 0.001, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02390546398814444 0.020527903107714917 {'C': 0.001, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02390546398814444 0.020527903107714917 {'C': 0.001, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.1}
# 0.023921397023300067 0.01898470086858474 {'C': 0.005, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.1}
# 0.023921397023300067 0.01898470086858474 {'C': 0.005, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.1}
# 0.023921397023300067 0.01898470086858474 {'C': 0.005, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02392920625823533 0.019680438520226926 {'C': 0.005, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.01}
# 0.02392920625823533 0.019680438520226926 {'C': 0.005, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.01}
# 0.02392920625823533 0.019680438520226926 {'C': 0.005, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.01}
# 0.023930238427029966 0.02019755896906836 {'C': 0.005, 'degree': 9, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023930238427029966 0.02019755896906836 {'C': 0.005, 'degree': 6, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023930238427029966 0.02019755896906836 {'C': 0.005, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.02393124339339135 0.020189851583075118 {'C': 0.005, 'degree': 9, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02393124339339135 0.020189851583075118 {'C': 0.005, 'degree': 6, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02393124339339135 0.020189851583075118 {'C': 0.005, 'degree': 3, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.023945783591759043 0.009313304908877017 {'C': 0.1, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023945783591759043 0.009313304908877017 {'C': 0.1, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023945783591759043 0.009313304908877017 {'C': 0.1, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.1}
# 0.02394846727581113 0.01740327654395398 {'C': 0.01, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02394846727581113 0.01740327654395398 {'C': 0.01, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02394846727581113 0.01740327654395398 {'C': 0.01, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.1}
# 0.023960079440319425 0.011748957859789603 {'C': 0.05, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023960079440319425 0.011748957859789603 {'C': 0.05, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023960079440319425 0.011748957859789603 {'C': 0.05, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.1}
# 0.02397790350011692 0.018883129479765615 {'C': 0.01, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.01}
# 0.02397790350011692 0.018883129479765615 {'C': 0.01, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.01}
# 0.02397790350011692 0.018883129479765615 {'C': 0.01, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.01}
# 0.023982459139595062 0.02056810136469253 {'C': 0.001, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023982459139595062 0.02056810136469253 {'C': 0.001, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023982459139595062 0.02056810136469253 {'C': 0.001, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023984878264002384 0.020732573774136998 {'C': 0.001, 'degree': 9, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.023984878264002384 0.020732573774136998 {'C': 0.001, 'degree': 6, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.023984878264002384 0.020732573774136998 {'C': 0.001, 'degree': 3, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.023985314273413872 0.0207311864038222 {'C': 0.001, 'degree': 9, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.023985314273413872 0.0207311864038222 {'C': 0.001, 'degree': 6, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.023985314273413872 0.0207311864038222 {'C': 0.001, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.023990225110413772 0.008201117338637154 {'C': 1.0, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023990225110413772 0.008201117338637154 {'C': 1.0, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023990225110413772 0.008201117338637154 {'C': 1.0, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023994069424407995 0.020592065546294117 {'C': 0.001, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.01}
# 0.023994069424407995 0.020592065546294117 {'C': 0.001, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.01}
# 0.023994069424407995 0.020592065546294117 {'C': 0.001, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.01}
# 0.02399453720490299 0.018984449861533245 {'C': 0.005, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.1}
# 0.02399453720490299 0.018984449861533245 {'C': 0.005, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.1}
# 0.02399453720490299 0.018984449861533245 {'C': 0.005, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.1}
# 0.023996514957622447 0.010874183070995495 {'C': 0.05, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.1}
# 0.023996514957622447 0.010874183070995495 {'C': 0.05, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.1}
# 0.023996514957622447 0.010874183070995495 {'C': 0.05, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02399722448086664 0.007074465946375794 {'C': 0.1, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02399722448086664 0.007074465946375794 {'C': 0.1, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02399722448086664 0.007074465946375794 {'C': 0.1, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.1}
# 0.024006195558942844 0.017523725212115093 {'C': 0.01, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.1}
# 0.024006195558942844 0.017523725212115093 {'C': 0.01, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.1}
# 0.024006195558942844 0.017523725212115093 {'C': 0.01, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.1}
# 0.024011084422681864 0.019694273229798658 {'C': 0.01, 'degree': 9, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024011084422681864 0.019694273229798658 {'C': 0.01, 'degree': 6, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024011084422681864 0.019694273229798658 {'C': 0.01, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024011600520499464 0.019690109872483465 {'C': 0.01, 'degree': 9, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.024011600520499464 0.019690109872483465 {'C': 0.01, 'degree': 6, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.024011600520499464 0.019690109872483465 {'C': 0.01, 'degree': 3, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02402563838377285 0.019905076274431093 {'C': 0.005, 'degree': 9, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.02402563838377285 0.019905076274431093 {'C': 0.005, 'degree': 6, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.02402563838377285 0.019905076274431093 {'C': 0.005, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.024025871040376467 0.019899845556678723 {'C': 0.005, 'degree': 9, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024025871040376467 0.019899845556678723 {'C': 0.005, 'degree': 6, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024025871040376467 0.019899845556678723 {'C': 0.005, 'degree': 3, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024034854610426114 0.018536358717889653 {'C': 0.01, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024034854610426114 0.018536358717889653 {'C': 0.01, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024034854610426114 0.018536358717889653 {'C': 0.01, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024036435371052347 0.01939501584118458 {'C': 0.005, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024036435371052347 0.01939501584118458 {'C': 0.005, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024036435371052347 0.01939501584118458 {'C': 0.005, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024067825475716547 0.019281621179049368 {'C': 0.01, 'degree': 9, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024067825475716547 0.019281621179049368 {'C': 0.01, 'degree': 6, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024067825475716547 0.019281621179049368 {'C': 0.01, 'degree': 3, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024067966176234058 0.019295845170185774 {'C': 0.01, 'degree': 9, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.024067966176234058 0.019295845170185774 {'C': 0.01, 'degree': 6, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.024067966176234058 0.019295845170185774 {'C': 0.01, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.02407175718698075 0.0018140359019113278 {'C': 1.0, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02407175718698075 0.0018140359019113278 {'C': 1.0, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02407175718698075 0.0018140359019113278 {'C': 1.0, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.1}
# 0.02409618292658108 0.016366435879512545 {'C': 0.05, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.01}
# 0.02409618292658108 0.016366435879512545 {'C': 0.05, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.01}
# 0.02409618292658108 0.016366435879512545 {'C': 0.05, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.01}
# 0.02412198863830276 0.015206264292653773 {'C': 0.1, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.01}
# 0.02412198863830276 0.015206264292653773 {'C': 0.1, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.01}
# 0.02412198863830276 0.015206264292653773 {'C': 0.1, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.01}
# 0.0241242606303864 0.016417001206839005 {'C': 0.05, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.01}
# 0.0241242606303864 0.016417001206839005 {'C': 0.05, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.01}
# 0.0241242606303864 0.016417001206839005 {'C': 0.05, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.01}
# 0.02414505294472943 0.015149474708324999 {'C': 0.1, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.01}
# 0.02414505294472943 0.015149474708324999 {'C': 0.1, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.01}
# 0.02414505294472943 0.015149474708324999 {'C': 0.1, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.01}
# 0.024145851167415366 0.01076056842635697 {'C': 1.0, 'degree': 9, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024145851167415366 0.01076056842635697 {'C': 1.0, 'degree': 6, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024145851167415366 0.01076056842635697 {'C': 1.0, 'degree': 3, 'epsilon': 0.01, 'gamma': 0.01}
# 0.024237860191893765 0.009465304162838107 {'C': 1.0, 'degree': 9, 'epsilon': 0.001, 'gamma': 0.01}
# 0.024237860191893765 0.009465304162838107 {'C': 1.0, 'degree': 6, 'epsilon': 0.001, 'gamma': 0.01}
# 0.024237860191893765 0.009465304162838107 {'C': 1.0, 'degree': 3, 'epsilon': 0.001, 'gamma': 0.01}
# 0.024409678149607133 0.017825133371371732 {'C': 0.05, 'degree': 9, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024409678149607133 0.017825133371371732 {'C': 0.05, 'degree': 6, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024409678149607133 0.017825133371371732 {'C': 0.05, 'degree': 3, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.02441483781276475 0.017830230743268886 {'C': 0.05, 'degree': 9, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.02441483781276475 0.017830230743268886 {'C': 0.05, 'degree': 6, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.02441483781276475 0.017830230743268886 {'C': 0.05, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.024492704433840065 0.018124190450957582 {'C': 0.05, 'degree': 9, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024492704433840065 0.018124190450957582 {'C': 0.05, 'degree': 6, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024492704433840065 0.018124190450957582 {'C': 0.05, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024498174342737936 0.018117071942104032 {'C': 0.05, 'degree': 9, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.024498174342737936 0.018117071942104032 {'C': 0.05, 'degree': 6, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.024498174342737936 0.018117071942104032 {'C': 0.05, 'degree': 3, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02457770690691344 0.017265077228965534 {'C': 0.1, 'degree': 9, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.02457770690691344 0.017265077228965534 {'C': 0.1, 'degree': 6, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.02457770690691344 0.017265077228965534 {'C': 0.1, 'degree': 3, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.024583595439432455 0.017266065071190034 {'C': 0.1, 'degree': 9, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.024583595439432455 0.017266065071190034 {'C': 0.1, 'degree': 6, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.024583595439432455 0.017266065071190034 {'C': 0.1, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.024769970860075433 0.01744537015544821 {'C': 0.1, 'degree': 9, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024769970860075433 0.01744537015544821 {'C': 0.1, 'degree': 6, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024769970860075433 0.01744537015544821 {'C': 0.1, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.024777241329341105 0.017447648923727684 {'C': 0.1, 'degree': 9, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.024777241329341105 0.017447648923727684 {'C': 0.1, 'degree': 6, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.024777241329341105 0.017447648923727684 {'C': 0.1, 'degree': 3, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02633993064044844 0.014172742942118316 {'C': 1.0, 'degree': 9, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.02633993064044844 0.014172742942118316 {'C': 1.0, 'degree': 6, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.02633993064044844 0.014172742942118316 {'C': 1.0, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto'}
# 0.026371458958674328 0.014137503286204781 {'C': 1.0, 'degree': 9, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.026371458958674328 0.014137503286204781 {'C': 1.0, 'degree': 6, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.026371458958674328 0.014137503286204781 {'C': 1.0, 'degree': 3, 'epsilon': 0.01, 'gamma': 'scale'}
# 0.026460512766692902 0.013745770565568619 {'C': 1.0, 'degree': 9, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.026460512766692902 0.013745770565568619 {'C': 1.0, 'degree': 6, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.026460512766692902 0.013745770565568619 {'C': 1.0, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.02650061962578796 0.01369912270601444 {'C': 1.0, 'degree': 9, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02650061962578796 0.01369912270601444 {'C': 1.0, 'degree': 6, 'epsilon': 0.001, 'gamma': 'scale'}
# 0.02650061962578796 0.01369912270601444 {'C': 1.0, 'degree': 3, 'epsilon': 0.001, 'gamma': 'scale'}

# %%
pd.DataFrame({"Test": val_scores, "Train": train_scores}).plot(figsize=(16, 8))

# %% [markdown]
# Looks like it is underfitting.

# %%
dump(svr_cv.best_estimator_, "/content/drive/MyDrive/Dissertation Models/svr-1")
# Out:
# ['/content/drive/MyDrive/Dissertation Models/svr-1']

# %% [markdown]
# ## SVR 2 (BEST SVR)

# %%
svr = SVR(kernel="rbf")

params = [
        {
            "C": [0.0001, 0.0005, 0.001, 0.003],
            "epsilon": [0.0005, 0.001, 0.005],
            "gamma": ["auto"], 
            "degree": [1, 2, 3, 4]
        }
        ]


tscv = TimeSeriesSplit(n_splits=5)
svr_cv = GridSearchCV(estimator=svr, cv=tscv,
                        param_grid=params,
                        scoring='neg_mean_squared_error', 
                        return_train_score=True)

start = time.time()
svr_cv.fit(X_train, y_train)
duration = time.time() - start
print(f'Took {duration:.3f} seconds')
# Out:
# Took 117.371 seconds

# %%
svr_cv.best_params_
# Out:
# {'C': 0.0005, 'degree': 1, 'epsilon': 0.001, 'gamma': 'auto'}

# %%
print(f"RMSE CV: {np.sqrt(-svr_cv.best_score_)}")
print(f"MDA TRAINING SET: {get_mda(y_train, svr_cv.predict(X_train))}")
# Out:
# RMSE CV: 0.023898373282462373
# MDA TRAINING SET: 0.6142259414225941

# %%
plt.figure(figsize=(14,6))
 
y_hat_train = svr_cv.predict(X_train)
plt.plot(y_train, label="Actual")
plt.plot((y_hat_train), label="Predicted")
plt.legend()
plt.title("Train Dataset")
# Out:
# Text(0.5, 1.0, 'Train Dataset')

# %%
val_scores = svr_cv.cv_results_["mean_test_score"]
train_scores = svr_cv.cv_results_["mean_train_score"]
params = [str(x) for x in svr_cv.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 0.02389837328096174 0.02088210081607213 {'C': 0.0005, 'degree': 4, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.02389837328096174 0.02088210081607213 {'C': 0.0005, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.02389837328096174 0.02088210081607213 {'C': 0.0005, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.02389837328096174 0.02088210081607213 {'C': 0.0005, 'degree': 1, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023900020869824855 0.020778577586618576 {'C': 0.001, 'degree': 4, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023900020869824855 0.020778577586618576 {'C': 0.001, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023900020869824855 0.020778577586618576 {'C': 0.001, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023900020869824855 0.020778577586618576 {'C': 0.001, 'degree': 1, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.02390306582304269 0.02090590235811165 {'C': 0.0005, 'degree': 4, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.02390306582304269 0.02090590235811165 {'C': 0.0005, 'degree': 3, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.02390306582304269 0.02090590235811165 {'C': 0.0005, 'degree': 2, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.02390306582304269 0.02090590235811165 {'C': 0.0005, 'degree': 1, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023904429825734118 0.021003933323004827 {'C': 0.0001, 'degree': 4, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023904429825734118 0.021003933323004827 {'C': 0.0001, 'degree': 3, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023904429825734118 0.021003933323004827 {'C': 0.0001, 'degree': 2, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023904429825734118 0.021003933323004827 {'C': 0.0001, 'degree': 1, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023905401162863524 0.02080781157413685 {'C': 0.001, 'degree': 4, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023905401162863524 0.02080781157413685 {'C': 0.001, 'degree': 3, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023905401162863524 0.02080781157413685 {'C': 0.001, 'degree': 2, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023905401162863524 0.02080781157413685 {'C': 0.001, 'degree': 1, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023906678624070494 0.020995982235554277 {'C': 0.0001, 'degree': 4, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023906678624070494 0.020995982235554277 {'C': 0.0001, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023906678624070494 0.020995982235554277 {'C': 0.0001, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023906678624070494 0.020995982235554277 {'C': 0.0001, 'degree': 1, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023911796910287497 0.020455277312390788 {'C': 0.003, 'degree': 4, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023911796910287497 0.020455277312390788 {'C': 0.003, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023911796910287497 0.020455277312390788 {'C': 0.003, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023911796910287497 0.020455277312390788 {'C': 0.003, 'degree': 1, 'epsilon': 0.001, 'gamma': 'auto'}
# 0.023915988849752073 0.020506600138862654 {'C': 0.003, 'degree': 4, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023915988849752073 0.020506600138862654 {'C': 0.003, 'degree': 3, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023915988849752073 0.020506600138862654 {'C': 0.003, 'degree': 2, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.023915988849752073 0.020506600138862654 {'C': 0.003, 'degree': 1, 'epsilon': 0.0005, 'gamma': 'auto'}
# 0.02396106966798913 0.02026625988544567 {'C': 0.003, 'degree': 4, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.02396106966798913 0.02026625988544567 {'C': 0.003, 'degree': 3, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.02396106966798913 0.02026625988544567 {'C': 0.003, 'degree': 2, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.02396106966798913 0.02026625988544567 {'C': 0.003, 'degree': 1, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023964749528150107 0.021044024366577457 {'C': 0.0001, 'degree': 4, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023964749528150107 0.021044024366577457 {'C': 0.0001, 'degree': 3, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023964749528150107 0.021044024366577457 {'C': 0.0001, 'degree': 2, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023964749528150107 0.021044024366577457 {'C': 0.0001, 'degree': 1, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023969470409037633 0.020901211277227837 {'C': 0.0005, 'degree': 4, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023969470409037633 0.020901211277227837 {'C': 0.0005, 'degree': 3, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023969470409037633 0.020901211277227837 {'C': 0.0005, 'degree': 2, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023969470409037633 0.020901211277227837 {'C': 0.0005, 'degree': 1, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023971894451894928 0.020725380160489176 {'C': 0.001, 'degree': 4, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023971894451894928 0.020725380160489176 {'C': 0.001, 'degree': 3, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023971894451894928 0.020725380160489176 {'C': 0.001, 'degree': 2, 'epsilon': 0.005, 'gamma': 'auto'}
# 0.023971894451894928 0.020725380160489176 {'C': 0.001, 'degree': 1, 'epsilon': 0.005, 'gamma': 'auto'}

# %%
pd.DataFrame({"Test": val_scores, "Train": train_scores}).plot(figsize=(16, 8))

# %% [markdown]
# Now it's too restricted and it has not been able to properrly learn from the training set.

# %%
dump(svr_cv.best_estimator_, "/content/drive/MyDrive/Dissertation Models/svr-2.joblib")
# Out:
# ['/content/drive/MyDrive/Dissertation Models/svr-2.joblib']

# %% [markdown]
# ## RF 1 (BEST RF)

# %%
rf = RandomForestRegressor(random_state=42)

params = [
    {
     'n_estimators': [50, 100, 150], 
     'max_depth': [5, None]
     },
]

tscv = TimeSeriesSplit(n_splits=5)
rf_cv = GridSearchCV(estimator=rf, cv=tscv,
                        param_grid=params,
                        scoring='neg_mean_squared_error', 
                        return_train_score=True)

start = time.time()
rf_cv.fit(X_train, y_train)
duration = time.time() - start
print(f'Took {duration:.3f} seconds')
# Out:
# Took 333.400 seconds

# %%
rf_cv.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 150}

# %%
print(f"RMSE CV: {np.sqrt(-rf_cv.best_score_)}")
print(f"MDA TRAINING SET: {get_mda(y_train, rf_cv.predict(X_train))}")
# Out:
# RMSE CV: 0.024282435591499833
# MDA TRAINING SET: 0.49539748953974894

# %%
plt.subplot2grid

plt.figure(figsize=(14,6))
 
y_hat_train = rf_cv.predict(X_train)
plt.plot(y_train, label="Actual")
plt.plot((y_hat_train), label="Predicted")
plt.legend()
plt.title("Train Dataset")
# Out:
# Text(0.5, 1.0, 'Train Dataset')

# %%
val_scores = rf_cv.cv_results_["mean_test_score"]
train_scores = rf_cv.cv_results_["mean_train_score"]
params = [str(x) for x in rf_cv.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 0.024282435591499833 0.016664117343290846 {'max_depth': 5, 'n_estimators': 150}
# 0.024295862872980724 0.016788161342359356 {'max_depth': 5, 'n_estimators': 50}
# 0.024336483892184 0.016670744131267536 {'max_depth': 5, 'n_estimators': 100}
# 0.024601049245669745 0.008741348943886583 {'max_depth': None, 'n_estimators': 150}
# 0.024606532194204295 0.008789645751986312 {'max_depth': None, 'n_estimators': 100}
# 0.02469628903126685 0.009019789935329564 {'max_depth': None, 'n_estimators': 50}

# %%
pd.DataFrame({"Test": val_scores, "Train": train_scores}).plot(figsize=(16, 8))

# %% [markdown]
# It started underfitting.

# %%
dump(svr_cv.best_estimator_, "/content/drive/MyDrive/Dissertation Models/rf-1")
# Out:
# ['models/rf_1.joblib']

# %% [markdown]
# ## RF 2

# %%
rf = RandomForestRegressor(random_state=42)

params = [
    {
     'n_estimators': [150, 200, 250], 
     'max_depth': [3, 5, 7]
     },
]

tscv = TimeSeriesSplit(n_splits=5)
rf_cv = GridSearchCV(estimator=rf, cv=tscv,
                        param_grid=params,
                        scoring='neg_mean_squared_error', 
                        return_train_score=True)

start = time.time()
rf_cv.fit(X_train, y_train)
duration = time.time() - start
print(f'Took {duration:.3f} seconds')
# Out:
# Took 524.183 seconds

# %%
rf_cv.best_params_
# Out:
# {'max_depth': 3, 'n_estimators': 150}

# %%
print(f"RMSE CV: {np.sqrt(-rf_cv.best_score_)}")
print(f"MDA TRAINING SET: {get_mda(y_train, rf_cv.predict(X_train))}")
# Out:
# RMSE CV: 0.024133594494241378
# MDA TRAINING SET: 0.37740585774058577

# %%
plt.figure(figsize=(16,6))
 
y_hat_train = rf_cv.predict(X_train)
plt.plot(y_train, label="Actual")
plt.plot((y_hat_train), label="Predicted")
plt.legend()
plt.title("Train Dataset")
# Out:
# Text(0.5, 1.0, 'Train Dataset')

# %%
val_scores = rf_cv.cv_results_["mean_test_score"]
train_scores = rf_cv.cv_results_["mean_train_score"]
params = [str(x) for x in rf_cv.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 0.024133594494241378 0.018523847468188834 {'max_depth': 3, 'n_estimators': 150}
# 0.02414983245604462 0.018515039155849476 {'max_depth': 3, 'n_estimators': 250}
# 0.024151418505223142 0.01852805258215334 {'max_depth': 3, 'n_estimators': 200}
# 0.024282435591499833 0.016664117343290846 {'max_depth': 5, 'n_estimators': 150}
# 0.02432020459568689 0.016618139951657406 {'max_depth': 5, 'n_estimators': 250}
# 0.02433384439183908 0.01665206824671759 {'max_depth': 5, 'n_estimators': 200}
# 0.024353889309430755 0.014832440652280381 {'max_depth': 7, 'n_estimators': 150}
# 0.024400923550500365 0.014764550831445898 {'max_depth': 7, 'n_estimators': 250}
# 0.024420768892437716 0.01481739164045226 {'max_depth': 7, 'n_estimators': 200}

# %%
pd.DataFrame({"Test": val_scores, "Train": train_scores}).plot(figsize=(16, 8))

# %%
#Save the model
dump(rf_cv.best_estimator_, '/content/drive/MyDrive/Dissertation Models/rf-2.joblib')
# Out:
# ['/content/drive/MyDrive/Dissertation Models/rf-2.joblib']

# %% [markdown]
# ## ADA 1

# %%
ada = AdaBoostRegressor(random_state=42)

params = {
        "n_estimators": [10, 20, 30, 40], 
        'learning_rate': [0.5, 1, 1.5]
}

tscv = TimeSeriesSplit(n_splits=5)
ada_cv = GridSearchCV(estimator=ada, cv=tscv,
                        param_grid=params,
                        scoring='neg_mean_squared_error', 
                        return_train_score=True)

start = time.time()
ada_cv.fit(X_train, y_train)
duration = time.time() - start
print(f'Took {duration:.3f} seconds')
# Out:
# Took 60.730 seconds

# %%
ada_cv.best_params_
# Out:
# {'learning_rate': 0.5, 'n_estimators': 20}

# %%
print(f"RMSE CV: {np.sqrt(-ada_cv.best_score_)}")
print(f"MDA TRAINING SET: {get_mda(y_train, ada_cv.predict(X_train))}")
# Out:
# RMSE CV: 0.02421042079347444
# MDA TRAINING SET: 0.299581589958159

# %%
plt.figure(figsize=(16,6))
 
y_hat_train = ada_cv.predict(X_train)
plt.plot(y_train, label="Actual")
plt.plot((y_hat_train), label="Predicted")
plt.legend()
plt.title("Train Dataset")
# Out:
# Text(0.5, 1.0, 'Train Dataset')

# %%
val_scores = ada_cv.cv_results_["mean_test_score"]
train_scores = ada_cv.cv_results_["mean_train_score"]
params = [str(x) for x in ada_cv.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 0.02421042079347444 0.017690920742831157 {'learning_rate': 0.5, 'n_estimators': 20}
# 0.024241587252429052 0.018442674836674826 {'learning_rate': 0.5, 'n_estimators': 10}
# 0.02424723160116252 0.017403144128478952 {'learning_rate': 0.5, 'n_estimators': 30}
# 0.024258487376359234 0.016975810982106116 {'learning_rate': 1, 'n_estimators': 20}
# 0.024261321600810015 0.017712086509791312 {'learning_rate': 1, 'n_estimators': 10}
# 0.0243026715600622 0.0171050049095866 {'learning_rate': 0.5, 'n_estimators': 40}
# 0.024385997385260087 0.016674576908382394 {'learning_rate': 1, 'n_estimators': 30}
# 0.02445271317845874 0.017433713914492204 {'learning_rate': 1.5, 'n_estimators': 10}
# 0.02448958407461529 0.016591443863244928 {'learning_rate': 1, 'n_estimators': 40}
# 0.024593594076857267 0.01691149932012711 {'learning_rate': 1.5, 'n_estimators': 20}
# 0.024667131450202058 0.016632760436240856 {'learning_rate': 1.5, 'n_estimators': 30}
# 0.024669235721456025 0.0165447879918823 {'learning_rate': 1.5, 'n_estimators': 40}

# %%
pd.DataFrame({"Test": val_scores, "Train": train_scores}).plot(figsize=(16, 8))

# %%
#Save the model
dump(ada_cv.best_estimator_, '/content/drive/MyDrive/Dissertation Models/ada-1.joblib')
# Out:
# ['/content/drive/MyDrive/Dissertation Models/ada-1.joblib']

# %% [markdown]
# ## XGBOST - BEST MDA OF ALL MODELS 63% - RMSE 0.025

# %%
xgb = XGBRegressor(random_state=42, n_jobs=-1)

params = {
        "n_estimators": [50, 100, 150], 
        'max_depth': [5, None], 
    'min_child_weight': [1, 2]
}


tscv = TimeSeriesSplit(n_splits=5)
xgb_cv = GridSearchCV(estimator=xgb, cv=tscv,
                        param_grid=params,
                        scoring='neg_mean_squared_error', 
                        return_train_score=True, 
                        n_jobs=-1)

start = time.time()
xgb_cv.fit(X_train, y_train)
duration = time.time() - start
print(f'Took {duration:.3f} seconds')
# Out:
# [10:00:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Took 53.283 seconds

# %%
xgb_cv.best_params_
# Out:
# {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 50}

# %%
print(f"RMSE CV: {np.sqrt(-xgb_cv.best_score_)}")
print(f"MDA TRAINING SET: {get_mda(y_train, xgb_cv.predict(X_train))}")
# Out:
# RMSE CV: 0.025732996215350943
# MDA TRAINING SET: 0.6376569037656904

# %%
plt.figure(figsize=(16,6))
 
y_hat_train = xgb_cv.predict(X_train)
plt.plot(y_train, label="Actual")
plt.plot((y_hat_train), label="Predicted")
plt.legend()
plt.title("Train Dataset")
# Out:
# Text(0.5, 1.0, 'Train Dataset')

# %%
val_scores = xgb_cv.cv_results_["mean_test_score"]
train_scores = xgb_cv.cv_results_["mean_train_score"]
params = [str(x) for x in xgb_cv.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 0.025732996215350943 0.01255670698368885 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 50}
# 0.025922637663525604 0.007268267668815076 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 100}
# 0.026115396347332898 0.004633702246598034 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 150}
# 0.026775189669675473 0.012327813540676396 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 50}
# 0.027039061360687528 0.007123573662765328 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 100}
# 0.027239056992811594 0.0045277346641616496 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 150}
# nan nan {'max_depth': None, 'min_child_weight': 1, 'n_estimators': 50}
# nan nan {'max_depth': None, 'min_child_weight': 1, 'n_estimators': 100}
# nan nan {'max_depth': None, 'min_child_weight': 1, 'n_estimators': 150}
# nan nan {'max_depth': None, 'min_child_weight': 2, 'n_estimators': 50}
# nan nan {'max_depth': None, 'min_child_weight': 2, 'n_estimators': 100}
# nan nan {'max_depth': None, 'min_child_weight': 2, 'n_estimators': 150}

# %%
pd.DataFrame({"Test": val_scores, "Train": train_scores}).plot(figsize=(16, 8))

# %%
#Save the model
dump(xgb_cv.best_estimator_, '/content/drive/MyDrive/Dissertation Models/xgb-1.joblib')
# Out:
# ['/content/drive/MyDrive/Dissertation Models/xgb-1.joblib']

# %% [markdown]
# ## XGBOOST 2

# %%
xgb = XGBRegressor(random_state=42, n_jobs=-1)

params = {
        "n_estimators": [30, 40, 50, 60, 70, 80], 
        'max_depth': [3, 5, 7, ], 
        'min_child_weight': [1, 2]
}


tscv = TimeSeriesSplit(n_splits=5)
xgb_cv = GridSearchCV(estimator=xgb, cv=tscv,
                        param_grid=params,
                        scoring='neg_mean_squared_error', 
                        return_train_score=True, 
                        n_jobs=-1)

start = time.time()
xgb_cv.fit(X_train, y_train)
duration = time.time() - start
print(f'Took {duration:.3f} seconds')
# Out:
# [10:10:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Took 141.384 seconds

# %%
xgb_cv.best_params_
# Out:
# {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 60}

# %%
print(f"RMSE CV: {np.sqrt(-xgb_cv.best_score_)}")
print(f"MDA TRAINING SET: {get_mda(y_train, xgb_cv.predict(X_train))}")
# Out:
# RMSE CV: 0.025374642148220907
# MDA TRAINING SET: 0.49456066945606697

# %%
plt.figure(figsize=(16,6))
 
y_hat_train = xgb_cv.predict(X_train)
plt.plot(y_train, label="Actual")
plt.plot((y_hat_train), label="Predicted")
plt.legend()
plt.title("Train Dataset")
# Out:
# Text(0.5, 1.0, 'Train Dataset')

# %%
val_scores = xgb_cv.cv_results_["mean_test_score"]
train_scores = xgb_cv.cv_results_["mean_train_score"]
params = [str(x) for x in xgb_cv.cv_results_["params"]]

for val_score, train_score, param in sorted(zip(val_scores, train_scores, params), reverse=True):
    print(np.sqrt(-val_score), np.sqrt(-train_score), param)
# Out:
# 0.025374642148220907 0.01498636648813375 {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 60}
# 0.025439843493504515 0.01604610427351573 {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 50}
# 0.025532992714850492 0.014233805343995602 {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 70}
# 0.025588499752285523 0.013599261295845662 {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 80}
# 0.02560218449208655 0.010801329920916149 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 60}
# 0.025677211915251522 0.009636982348787739 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 70}
# 0.025723719806472048 0.008721931288592555 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 80}
# 0.025732996215350943 0.01255670698368885 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 50}
# 0.025842187504296926 0.014962063377386458 {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 60}
# 0.02595717378754321 0.014271149911077988 {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 70}
# 0.026005842147171627 0.015998813375149707 {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50}
# 0.026072809898143385 0.0061718421621077164 {'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 70}
# 0.026077170045517684 0.004946360986512584 {'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 80}
# 0.026085600845210267 0.007747893324079906 {'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 60}
# 0.02609362700134716 0.013535348248059135 {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 80}
# 0.02623474463164771 0.009851002095637485 {'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 50}
# 0.026641804061084545 0.010637136718782901 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 60}
# 0.026689410244051037 0.018656048366199985 {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 40}
# 0.026692584594308014 0.009506853968036287 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 70}
# 0.026775189669675473 0.012327813540676396 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 50}
# 0.026798416997643588 0.008599941136629942 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 80}
# 0.027007606476937403 0.016151603708959662 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 40}
# 0.027329823811854222 0.018476824457155667 {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 40}
# 0.027355479236655246 0.007098888390435432 {'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 60}
# 0.027396767782858614 0.005720490585021008 {'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 70}
# 0.027438477132303133 0.004606065135595132 {'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 80}
# 0.027563122109675903 0.014367482731117924 {'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 40}
# 0.027674428026080417 0.009185335234406136 {'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 50}
# 0.028060799254951384 0.01591675986056442 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 40}
# 0.02920575580602452 0.01377787747544431 {'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 40}
# 0.03411460596652504 0.02842571326348731 {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 30}
# 0.03441720729943161 0.02753334060461709 {'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 30}
# 0.0348426165712774 0.028282194071515873 {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 30}
# 0.03501821084708825 0.02703397936888019 {'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 30}
# 0.035515373543156405 0.027332363486168985 {'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 30}
# 0.03670432319045506 0.026753695615610102 {'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 30}

# %%
pd.DataFrame({"Test": val_scores, "Train": train_scores}).plot(figsize=(16, 8))

# %%
#Save the model
dump(xgb_cv.best_estimator_, '/content/drive/MyDrive/Dissertation Models/xgb-2.joblib')
# Out:
# ['/content/drive/MyDrive/Dissertation Models/xgb-2.joblib']

# %% [markdown]
# # Best Model Evaluation

# %%
# Load the SVR - Best model 
svr = load("/content/drive/MyDrive/Dissertation Models/svr-2.joblib")
ada = load("/content/drive/MyDrive/Dissertation Models/ada-1.joblib")
xgb = load("/content/drive/MyDrive/Dissertation Models/xgb-1.joblib")
# Out:
# [20:44:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
# SVR Evaluation
y_hat_svr = svr.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_hat_svr))
mda = get_mda(y_test, y_hat_svr)
print(f"SVR - RMSE: {rmse}")
print(f"SVR - MDA: {mda}")
print("")

# ADA Evaluation
y_hat_ada = ada.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_hat_ada))
mda = get_mda(y_test, y_hat_ada)
print(f"ADA - RMSE: {rmse}")
print(f"ADA - MDA: {mda}")
print("")

# XGBOOST Evaluation
y_hat_xgb = xgb.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_hat_xgb))
mda = get_mda(y_test, y_hat_xgb)
print(f"XGB - RMSE: {rmse}")
print(f"XGB - MDA: {mda}")
# Out:
# SVR - RMSE: 0.026073266111228375
# SVR - MDA: 0.5275590551181102
#
# ADA - RMSE: 0.026065176902015125
# ADA - MDA: 0.3228346456692913
#
# XGB - RMSE: 0.026693443070497713
# XGB - MDA: 0.4645669291338583

# %%
plt.subplot2grid

plt.figure(figsize=(16,4))

plt.plot(y_test, label="Actual")
plt.plot((y_hat_svr), label="Predicted")
plt.legend()
plt.grid()
plt.title("SVR Evaluation", fontsize=20)

plt.figure(figsize=(16,4))

plt.plot(y_test, label="Actual")
plt.plot((y_hat_ada), label="Predicted")
plt.legend()
plt.grid()
plt.title("ADA Evaluation", fontsize=20)

plt.figure(figsize=(16,4))

plt.plot(y_test, label="Actual")
plt.plot((y_hat_xgb), label="Predicted")
plt.legend()
plt.grid()
plt.title("XGB Evaluation", fontsize=20)
# Out:
# Text(0.5, 1.0, 'XGB Evaluation')
